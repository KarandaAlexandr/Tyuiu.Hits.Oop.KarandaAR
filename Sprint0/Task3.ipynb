// %% [markdown]
// <h1 style="color:DodgerBlue">Индивидальный проект</h1>

// %% [markdown]
// <h2 style="color:DodgerBlue">Название проекта:</h2>
//
// ----
//
// ### Вариант задания

// %% [markdown]
// <h2 style="color:DodgerBlue">Описание проекта:</h2>
//
// ----
//
// [ваш текст]

// %% [markdown]
// <h2 style="color:DodgerBlue">Реализация:</h2>
//
// ----

// %%
using System;

// Базовый класс
class Movie
{
    public string Title { get; set; }
    public string Director { get; set; }
    public int ReleaseYear { get; set; }

    public Movie(string title, string director, int releaseYear)
    {
        Title = title;
        Director = director;
        ReleaseYear = releaseYear;
    }

    public virtual string GetInfo()
    {
        return $"Название: {Title}, Режиссер: {Director}, Год: {ReleaseYear}";
    }

    public virtual void Watch()
    {
        Console.WriteLine($"Вы смотрите фильм \"{Title}\".");
    }

    public virtual void Rate(int rating)
    {
        Console.WriteLine($"Вы поставили фильму \"{Title}\" оценку {rating}/10.");
    }
}

// Документальный фильм
class Documentary : Movie
{
    public string Theme { get; set; }

    public Documentary(string title, string director, int releaseYear, string theme)
        : base(title, director, releaseYear)
    {
        Theme = theme;
    }

    public override void Watch()
    {
        Console.WriteLine($"Вы смотрите документальный фильм \"{Title}\" на тему: {Theme}.");
    }
}

// Игровой фильм
class FeatureFilm : Movie
{
    public string Genre { get; set; }

    public FeatureFilm(string title, string director, int releaseYear, string genre)
        : base(title, director, releaseYear)
    {
        Genre = genre;
    }

    public override void Rate(int rating)
    {
        if (Genre == "Ужасы" && rating > 8)
            Console.WriteLine($"Для ужастика \"{Title}\" это слишком щедро, но ладно: {rating}/10");
        else if (Genre == "Комедия" && rating < 5)
            Console.WriteLine($"Комедия \"{Title}\" заслуживает большего, чем {rating}/10!");
        else
            Console.WriteLine($"Вы оценили фильм \"{Title}\" ({Genre}) на {rating}/10.");
    }
}

// Анимационный фильм
class AnimatedMovie : Movie
{
    public string AnimationStudio { get; set; }

    public AnimatedMovie(string title, string director, int releaseYear, string studio)
        : base(title, director, releaseYear)
    {
        AnimationStudio = studio;
    }

    public override string GetInfo()
    {
        return $"{base.GetInfo()}, Анимационная студия: {AnimationStudio}";
    }
}

// Проверка работы
Documentary doc = new Documentary("Планета Земля", "Дэвид Аттенборо", 2006, "Природа");
FeatureFilm film = new FeatureFilm("Начало", "Кристофер Нолан", 2010, "Фантастика");
AnimatedMovie cartoon = new AnimatedMovie("Тайна Коко", "Ли Анкрич", 2017, "Pixar");

Console.WriteLine(doc.GetInfo());
doc.Watch();
doc.Rate(9);

Console.WriteLine();

Console.WriteLine(film.GetInfo());
film.Watch();
film.Rate(9);

Console.WriteLine();

Console.WriteLine(cartoon.GetInfo());
cartoon.Watch();
cartoon.Rate(10);
// Out:
// Название: Планета Земля, Режиссер: Дэвид Аттенборо, Год: 2006
// Вы смотрите документальный фильм "Планета Земля" на тему: Природа.
// Вы поставили фильму "Планета Земля" оценку 9/10.
//
// Название: Начало, Режиссер: Кристофер Нолан, Год: 2010
// Вы смотрите фильм "Начало".
// Вы оценили фильм "Начало" (Фантастика) на 9/10.
//
// Название: Тайна Коко, Режиссер: Ли Анкрич, Год: 2017, Анимационная студия: Pixar
// Вы смотрите фильм "Тайна Коко".
// Вы поставили фильму "Тайна Коко" оценку 10/10.
